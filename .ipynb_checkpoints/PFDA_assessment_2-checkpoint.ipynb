# %% [markdown]
# # PFDA assessment 2
# ***

# %% [markdown]
# ## Introduction
# ***

# %% [markdown]
# The purpose of this project is to have a look at the Wisconsin breast cancer dataset. I will do a statistical analysis of the dataset and then train a set of classifiers on the dataset and present classification performance results.

# %% [markdown]
# ### Loading the data
# ***

# %%
#Import required packages
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#read the data from csv file
data1 = pd.read_csv('data.csv')

# drop unwanted columns
data = data1.drop(['id','Unnamed: 32'], axis =1)

data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# The first thing to look at is the ratio of diagnosis between benign and malignant. We see that out of the 569 diagnosis we have 357 benign, 212 malignant. So about 37% malignant

# %%
# create bar chart comparing malignant/benign results
Label = data['diagnosis']
a = pd.DataFrame(Label.value_counts())
print(a)
a.plot(kind='bar', color = ['blue'], legend = None)
plt.xlabel("Diagnosis")
plt.ylabel("Frequency")
plt.title("Diagnosis Distribution")
plt.show()
# Out:
#    diagnosis
# B        357
# M        212

# %% [markdown]
# ##### Looking at the radius data

# %%
#creating pairplot for all datapoints

colours = {'B': "green", 'M': 'red'}

radius = data[['radius_mean','radius_se', 'radius_worst','diagnosis']]
sns.pairplot(radius, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### Looking at the texture data

# %%
texture = data[['texture_mean','texture_se', 'texture_worst','diagnosis']]
sns.pairplot(texture, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### Perimeter data

# %%
perimeter = data[['perimeter_mean','perimeter_se', 'perimeter_worst','diagnosis']]
sns.pairplot(perimeter, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### area data

# %%
area = data[['area_mean','area_se', 'area_worst','diagnosis']]
sns.pairplot(area, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### smoothness data

# %%
smoothness = data[['smoothness_mean','smoothness_se', 'smoothness_worst','diagnosis']]
sns.pairplot(smoothness, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### Compactness data

# %%
compactness = data[['compactness_mean','compactness_se', 'compactness_worst','diagnosis']]
sns.pairplot(compactness, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### Concavity data

# %%
concavity = data[['concavity_mean','concavity_se', 'concavity_worst','diagnosis']]
sns.pairplot(concavity, hue = 'diagnosis', palette=colours )

# %% [markdown]
# ##### Concave points

# %%
cp = data[['concave points_mean','concave points_se', 'concave points_worst','diagnosis']]
sns.pairplot(cp, hue = 'diagnosis', palette=colours )

# %%
#create heatmap

train = data.drop(['diagnosis'], axis = 1)

plt.figure(figsize=(10,10), dpi=100)
sns.heatmap(data.corr(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusion from data analysis
# ***

# %% [markdown]
# Looking at the above data, there are no  single categories where you can see a definitive difference between benign and malignant tumours, there is always some crossover between the 2, however some of the datapoints, such as concave points and area show some promise for accurate detection via the data, and overall taken together it should be possible to use this dataset to get a high accurate diagnosis rate, however it is worth bearing in mind it is quite a small dataset to use.

# %% [markdown]
# ## Looking at classifiers
# ***

# %% [markdown]
# The classifiers I will use for this project are Logistical regression, Random Forest, Decision Tree, Gaussian and K Nearest neighbour.
#
# Logistic regression is a statistical method used for classification problems. It is a type of generalized linear model (GLM) that is used to model a binary outcome (i.e. two possible outcomes such as success/failure or true/false) as a function of one or more predictor variables. The logistic regression model predicts the probability that an instance belongs to a particular class (for example, the probability that a customer will buy a product given certain features of that customer). Given this predicted probability, a threshold is chosen, such as 0.5, to convert the predicted probabilities into class predictions.
#
# Random forest is a supervised learning algorithm for classification and regression problems. It is an ensemble method, which means that it combines the predictions of multiple individual decision trees to create a more accurate and stable prediction. In a random forest, each decision tree is grown on a random sample of the data, and the features used to split each node in the tree are chosen at random from a subset of all features. This process helps to reduce overfitting and increase the overall performance of the model
#
# A decision tree is a type of supervised machine learning used to categorize or make predictions based on how a previous set of questions were answered. The model is a form of supervised learning, meaning that the model is trained and tested on a set of data that contains the desired categorization.
#
# The Gaussian Processes Classifier is a classification machine learning algorithm. Gaussian Processes are a generalization of the Gaussian probability distribution and can be used as the basis for sophisticated non-parametric machine learning algorithms for classification and regression
#
# The basic concept of the k-NN algorithm is that an object is classified by a majority vote of its neighbors, with the object being assigned to the class most common among its k nearest neighbors. The k-NN algorithm is a "lazy learning" algorithm, which means that it does not build a model ahead of time, but rather waits to make predictions until a new input is encountered. To classify a new input, the algorithm simply looks at the k closest training examples to that input and assigns the new input the class label that is most common among those k closest examples.

# %%
models = []
models.append(('Logistic Regression',LogisticRegression()))
models.append(('Random Forest',RandomForestClassifier()))
models.append(('Decision Tree',DecisionTreeClassifier()))
models.append(('Gaussian',GaussianNB()))
models.append(('K nearest neighbour',KNeighborsClassifier()))

# %%
#apply classifiers to training data and print results

acc = []   
names = []    

for name, model in models:
    
    acc_of_model = cross_val_score(model, X_train, y_train, cv=30, scoring='accuracy')
    
    acc.append(acc_of_model)

    names.append(name)

    Out = "%s: %f" % (name, acc_of_model.mean())
    print(Out)
# Out:
# C:\Users\jpqui\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jpqui\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# create boxplot comparring results

fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(acc)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# ## Conclusion
# ***

# %% [markdown]
# Looking at the below results I got from the above training sets I am showing that Random Forest classification is the most accurate with K nearest neighbour being the least accurate.
#
# Logistic Regression: 0.932418
# Random Forest: 0.957143
# Decision Tree: 0.916850
# Gaussian: 0.936813
# K nearest neighbour: 0.904396
